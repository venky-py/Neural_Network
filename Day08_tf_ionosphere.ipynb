# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import (accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay, f1_score)

# from utils.helper import fn_plot_confusion_matrix

# %%
def fn_plot_tf_hist(hist_df : pd.DataFrame):
    '''
    Note this function is specifically designed to plot Tensorflow training output
    Args:
      hist_df : pandas DataFrame with four columns
                For 'x' values, we will use index
                first column is accuracy
                Second column is loss
                third column is val_accuracy
                fourth column is val_loss
    '''
    fig, axes = plt.subplots(1,2 , figsize = (15,6)) # instantiate plot

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y4] == hist_df[y4].min()]
 
    ax = axes[0]

    hist_df.plot(y = [y2,y4], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y4].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.set_title('Errors')
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y1, y3], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy()-1, best[y3].to_numpy()[0]), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %%
# Some basic parameters
inpDir = '../../../input' # location where input data is stored
outDir = '../output' # location to store outputs
subDir = 'fashion_MNIST' # location of the images
modelDir = '../models'
altName = 'all_in'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
BATCH_SIZE = 32 # batch size for training   
TRAIN_SIZE = BATCH_SIZE * 9

EPOCHS = 100 # number of cycles to run
ALPHA = 0.001 # learning rate

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (9,9),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }

plt.rcParams.update(params) # update rcParams
CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
data_df = pd.read_csv('ionosphere.data', header=None)

# %%
X = data_df.drop(data_df.columns[-1], axis = 1).to_numpy()
y = data_df[data_df.columns[-1]].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size= TRAIN_SIZE, 
                                                    stratify=y, random_state=RANDOM_STATE)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((288, 34), (63, 34), (288,), (63,))

# %%
le = LabelEncoder()

y_train = le.fit_transform(y_train)

y_test = le.transform(y_test)

# %%
class_name = list(le.classes_)
class_name
# Out:
# ['b', 'g']

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
## Some Model Specification

initalizer = tf.keras.initializers.GlorotUniform(seed= RANDOM_STATE)
optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA)
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits= True)

model1 = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(shape = (34,)),

    tf.keras.layers.Dense(26, activation=tf.keras.activations.relu, kernel_initializer= initalizer),
    tf.keras.layers.Dense(18, activation=tf.keras.activations.relu, kernel_initializer= initalizer),
    tf.keras.layers.Dense(10, activation=tf.keras.activations.relu, kernel_initializer= initalizer),

    tf.keras.layers.Dense(2)
])

model1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 26)             │           910 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 18)             │           486 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 10)             │           190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │            22 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,608 (6.28 KB)
#  Trainable params: 1,608 (6.28 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# # Step 1 :  Loss function
# loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# # Step 2 : Optimizer
# #ALPHA=0.001
# optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA)

# # Step 3 :
model1.compile(loss=loss_fn, optimizer=optimizer, metrics=['accuracy'])

# Step 4 :
history = model1.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    validation_data=(X_test, y_test))

# Defaulted BATCH_SIZE, verbose =0
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.3760 - loss: 0.7618 - val_accuracy: 0.6190 - val_loss: 0.6492
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6754 - loss: 0.6217 - val_accuracy: 0.7143 - val_loss: 0.5875
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7491 - loss: 0.5596 - val_accuracy: 0.8254 - val_loss: 0.5406
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8245 - loss: 0.5064 - val_accuracy: 0.8413 - val_loss: 0.4953
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8868 - loss: 0.4411 - val_accuracy: 0.8413 - val_loss: 0.4579
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8773 - loss: 0.4050 - val_accuracy: 0.8571 - val_loss: 0.4252
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9254 - loss: 0.3539 - val_accuracy: 0.8571 - val_loss: 0.3947
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9205 - loss: 0.3107 - val_accuracy: 0.8571 - val_loss: 0.3636
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9001 - loss: 0.3075 - val_accuracy: 0.8571 - val_loss: 0.3350
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9306 - loss: 0.2436 - val_accuracy: 0.8730 - val_loss: 0.3161
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9381 - loss: 0.2229 - val_accuracy: 0.8730 - val_loss: 0.2965
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9487 - loss: 0.1889 - val_accuracy: 0.8730 - val_loss: 0.2813
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9400 - loss: 0.1904 - val_accuracy: 0.8730 - val_loss: 0.2658
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9540 - loss: 0.1610 - val_accuracy: 0.8730 - val_loss: 0.2576
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9653 - loss: 0.1501 - val_accuracy: 0.8730 - val_loss: 0.2414
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9615 - loss: 0.1317 - val_accuracy: 0.8889 - val_loss: 0.2274
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9437 - loss: 0.1509 - val_accuracy: 0.9048 - val_loss: 0.2125
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9611 - loss: 0.1337 - val_accuracy: 0.9048 - val_loss: 0.2087
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9552 - loss: 0.1221 - val_accuracy: 0.9048 - val_loss: 0.1997
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9628 - loss: 0.1077 - val_accuracy: 0.9048 - val_loss: 0.1891
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9705 - loss: 0.1044 - val_accuracy: 0.9206 - val_loss: 0.1850
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9677 - loss: 0.0998 - val_accuracy: 0.9365 - val_loss: 0.1759
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9568 - loss: 0.1061 - val_accuracy: 0.9365 - val_loss: 0.1694
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9611 - loss: 0.0930 - val_accuracy: 0.9524 - val_loss: 0.1646
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9646 - loss: 0.1129 - val_accuracy: 0.9524 - val_loss: 0.1574
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.0881 - val_accuracy: 0.9524 - val_loss: 0.1572
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9786 - loss: 0.0708 - val_accuracy: 0.9524 - val_loss: 0.1561
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9782 - loss: 0.0811 - val_accuracy: 0.9365 - val_loss: 0.1493
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9823 - loss: 0.0620 - val_accuracy: 0.9524 - val_loss: 0.1419
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9778 - loss: 0.0706 - val_accuracy: 0.9365 - val_loss: 0.1410
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9605 - loss: 0.1009 - val_accuracy: 0.9365 - val_loss: 0.1369
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9817 - loss: 0.0660 - val_accuracy: 0.9365 - val_loss: 0.1377
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9911 - loss: 0.0535 - val_accuracy: 0.9365 - val_loss: 0.1399
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9859 - loss: 0.0544 - val_accuracy: 0.9365 - val_loss: 0.1384
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9952 - loss: 0.0451 - val_accuracy: 0.9524 - val_loss: 0.1369
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9871 - loss: 0.0551 - val_accuracy: 0.9524 - val_loss: 0.1392
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9766 - loss: 0.0573 - val_accuracy: 0.9524 - val_loss: 0.1347
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9936 - loss: 0.0375 - val_accuracy: 0.9524 - val_loss: 0.1395
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9857 - loss: 0.0426 - val_accuracy: 0.9365 - val_loss: 0.1385
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9909 - loss: 0.0472 - val_accuracy: 0.9365 - val_loss: 0.1411
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9827 - loss: 0.0567 - val_accuracy: 0.9365 - val_loss: 0.1390
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9979 - loss: 0.0278 - val_accuracy: 0.9365 - val_loss: 0.1481
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9947 - loss: 0.0282 - val_accuracy: 0.9365 - val_loss: 0.1459
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9837 - loss: 0.0357 - val_accuracy: 0.9365 - val_loss: 0.1463
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9894 - loss: 0.0386 - val_accuracy: 0.9365 - val_loss: 0.1472
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9937 - loss: 0.0246 - val_accuracy: 0.9365 - val_loss: 0.1563
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9955 - loss: 0.0342 - val_accuracy: 0.9365 - val_loss: 0.1508
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.0389 - val_accuracy: 0.9365 - val_loss: 0.1549
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0232 - val_accuracy: 0.9365 - val_loss: 0.1601
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9962 - loss: 0.0238 - val_accuracy: 0.9365 - val_loss: 0.1650
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9974 - loss: 0.0229 - val_accuracy: 0.9365 - val_loss: 0.1666
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9959 - loss: 0.0192 - val_accuracy: 0.9365 - val_loss: 0.1675
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9939 - loss: 0.0390 - val_accuracy: 0.9365 - val_loss: 0.1650
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9969 - loss: 0.0204 - val_accuracy: 0.9365 - val_loss: 0.1714
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0230 - val_accuracy: 0.9365 - val_loss: 0.1772
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9989 - loss: 0.0192 - val_accuracy: 0.9365 - val_loss: 0.1813
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9955 - loss: 0.0254 - val_accuracy: 0.9365 - val_loss: 0.1794
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9993 - loss: 0.0154 - val_accuracy: 0.9365 - val_loss: 0.1878
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0142 - val_accuracy: 0.9365 - val_loss: 0.1884
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9955 - loss: 0.0228 - val_accuracy: 0.9365 - val_loss: 0.1843
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0169 - val_accuracy: 0.9365 - val_loss: 0.1898
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9908 - loss: 0.0331 - val_accuracy: 0.9365 - val_loss: 0.1898
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9979 - loss: 0.0152 - val_accuracy: 0.9365 - val_loss: 0.1981
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9989 - loss: 0.0113 - val_accuracy: 0.9365 - val_loss: 0.2062
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9993 - loss: 0.0111 - val_accuracy: 0.9365 - val_loss: 0.2106
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9979 - loss: 0.0149 - val_accuracy: 0.9365 - val_loss: 0.2043
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9939 - loss: 0.0205 - val_accuracy: 0.9365 - val_loss: 0.2100
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9965 - loss: 0.0181 - val_accuracy: 0.9365 - val_loss: 0.2157
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9983 - loss: 0.0142 - val_accuracy: 0.9365 - val_loss: 0.2225
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0140 - val_accuracy: 0.9365 - val_loss: 0.2215
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9908 - loss: 0.0241 - val_accuracy: 0.9365 - val_loss: 0.2213
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9989 - loss: 0.0119 - val_accuracy: 0.9365 - val_loss: 0.2338
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9993 - loss: 0.0095 - val_accuracy: 0.9365 - val_loss: 0.2361
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9984 - loss: 0.0086 - val_accuracy: 0.9365 - val_loss: 0.2337
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9989 - loss: 0.0088 - val_accuracy: 0.9365 - val_loss: 0.2384
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9939 - loss: 0.0155 - val_accuracy: 0.9365 - val_loss: 0.2415
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9908 - loss: 0.0185 - val_accuracy: 0.9365 - val_loss: 0.2512
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0108 - val_accuracy: 0.9365 - val_loss: 0.2577
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9908 - loss: 0.0189 - val_accuracy: 0.9365 - val_loss: 0.2580
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9965 - loss: 0.0113 - val_accuracy: 0.9365 - val_loss: 0.2632
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9993 - loss: 0.0076 - val_accuracy: 0.9365 - val_loss: 0.2728
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9993 - loss: 0.0062 - val_accuracy: 0.9365 - val_loss: 0.2715
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9939 - loss: 0.0120 - val_accuracy: 0.9365 - val_loss: 0.2670
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9955 - loss: 0.0094 - val_accuracy: 0.9365 - val_loss: 0.2708
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9994 - loss: 0.0064 - val_accuracy: 0.9365 - val_loss: 0.2841
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9939 - loss: 0.0110 - val_accuracy: 0.9365 - val_loss: 0.2826
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9991 - loss: 0.0059 - val_accuracy: 0.9365 - val_loss: 0.2908
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9989 - loss: 0.0059 - val_accuracy: 0.9365 - val_loss: 0.2913
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9993 - loss: 0.0047 - val_accuracy: 0.9365 - val_loss: 0.2889
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9979 - loss: 0.0060 - val_accuracy: 0.9365 - val_loss: 0.2945
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9365 - val_loss: 0.2981
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.9365 - val_loss: 0.3021
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.9365 - val_loss: 0.3055
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9996 - loss: 0.0042 - val_accuracy: 0.9365 - val_loss: 0.3147
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9365 - val_loss: 0.3156
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9365 - val_loss: 0.3117
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.9365 - val_loss: 0.3145
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9365 - val_loss: 0.3215
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9365 - val_loss: 0.3270
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9365 - val_loss: 0.3266

# %%
loss_df = pd.DataFrame(history.history)
loss_df.head()
# Out:
#    accuracy      loss  val_accuracy  val_loss
# 0  0.472222  0.714642      0.619048  0.649242
# 1  0.718750  0.609180      0.714286  0.587533
# 2  0.777778  0.539967      0.825397  0.540560
# 3  0.854167  0.483557      0.841270  0.495312
# 4  0.885417  0.432223      0.841270  0.457928

# %%
fn_plot_tf_hist(loss_df)
