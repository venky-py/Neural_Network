# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

# %% [markdown]
# # Image Processing with Neural Network
# ## Lecture 06 - Tensorflow Multiple Hidden Layer
#
# - Tensorflow
# - Moons Dataset
# - Decision Boundary
# - Loss curve
#
#
# <img src='../../../prasami_images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com" align = "left"/>

# %% [markdown]
# ## Import Statements

# %%
###-----------------
### Import Libraries
###-----------------

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

import tensorflow as tf

# %% [markdown]
# ## Setup Global Parameters

# %%
###----------------
### Some parameters
###----------------

RANDOM_STATE = 24 # REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
rng = np.random.default_rng(seed = RANDOM_STATE) # Set Random Seed for reproducible  results

NOISE = 0.2
EPOCHS = 100  # number of epochs
ALPHA = 0.001  # learning rate
N_SAMPLES = 1000
BATCH_SIZE = 32
TEST_SIZE = 0.2

# parameters for Matplotlib
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'large',
          'axes.titlesize':'large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
def fn_plot_decision_boundary(model, X, y):
    
    # initialize the figure
    fig, ax = plt.subplots(figsize = (8,5))
    
    # Small increment to create object function surface
    dm = 0.01
    
    # Range of X values (First feature)
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    
    # Range of Y values (Second feature)
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    
    # Create a grid to evaluate the object function
    xx, yy = np.meshgrid(np.arange(x_min, x_max, dm),
                         np.arange(y_min, y_max, dm))
    
    # flatten and stack
    # arrays will be stacked along their last axis after being upgraded to at least 2-D 
    # with 1’s post-pended to the shape (column vectors made out of 1-D arrays)
    XX = np.c_[xx.ravel(), yy.ravel()] 
    
    # list to collect predictions
    y_p = model.predict(XX)
    Z = y_p.argmax(axis=1) 
    Z = Z.reshape(xx.shape)

    ax.contourf(xx, yy, Z, alpha=0.6, cmap=plt.cm.Paired)
    ax.scatter(X[:, 0], X[:, 1], c=y,
                                  s=20, edgecolor='k', cmap=plt.cm.bwr)
    ax.set_title('Decision Boundary')

    ax.set_xlabel('A')
    ax.set_ylabel('B')
    plt.show()

# %% [markdown]
# ## Generate Data Set
# <div style="font-family: Arial; font-size:1.2em">
# Sklearn's dataset generator is good source of data for learning. To keep the example simple, I'll suggest  <a href="http://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html">make_moon</a> dataset generator.
# </div>

# %%
X, y = datasets.make_moons(n_samples=N_SAMPLES,
                           noise=NOISE, 
                           shuffle=True, 
                           random_state=RANDOM_STATE)
# X, y = datasets.make_circles(n_samples=N_SAMPLES,
#                            noise=NOISE, 
#                            shuffle=True, 
#                            random_state=RANDOM_STATE)
X[:5], y[:5]
# Out:
# (array([[ 0.90633951,  0.90267624],
#         [-1.11536828,  0.75579289],
#         [ 1.88769158,  0.4175967 ],
#         [-0.93345034, -0.02299851],
#         [-0.96872877,  0.06396285]]),
#  array([0, 0, 1, 0, 0], dtype=int64))

# %%
data_df = pd.DataFrame(X, columns=['A', 'B'])
data_df['target'] = y
data_df.head()
# Out:
#           A         B  target
# 0  0.906340  0.902676       0
# 1 -1.115368  0.755793       0
# 2  1.887692  0.417597       1
# 3 -0.933450 -0.022999       0
# 4 -0.968729  0.063963       0

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   target  1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %%
data_df.describe()
# Out:
#                  A            B      target
# count  1000.000000  1000.000000  1000.00000
# mean      0.490841     0.239025     0.50000
# std       0.898951     0.540082     0.50025
# min      -1.688795    -0.955280     0.00000
# 25%      -0.149565    -0.205090     0.00000
# 50%       0.500100     0.241163     0.50000
# 75%       1.095048     0.680394     1.00000
# max       2.419113     1.612075     1.00000

# %%
data_df['target'].value_counts().plot(kind = 'bar');

# %%
ax = sns.scatterplot(data=data_df, x='A', y='B', hue='target')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=TEST_SIZE,
                                                    stratify=y, 
                                                    random_state=RANDOM_STATE)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 2), (200, 2), (800,), (200,))

# %% [markdown]
# ### Define Model

# %%
tf.__version__
# Out:
# '2.18.0'

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(2,)),
    tf.keras.layers.Dense(5, activation='relu', name = 'layer1'),
    tf.keras.layers.Dense(5, activation='relu', name = 'layer2'),
    tf.keras.layers.Dense(4, activation='relu', name = 'layer3'),
    tf.keras.layers.Dense(3, activation='relu', name = 'layer4'),
    tf.keras.layers.Dense(2, name = 'output'),
], name = 'FirstModel')

# %% [markdown]
# -Functional API - user defined sequence
# -EXtend the model Class

# %%
X_train[:1].shape
# Out:
# (1, 2)

# %%
prediction=model(X_train[:1]).numpy()
prediction.sum()
# Out:
# 0.9303429

# %%
tf.nn.softmax(prediction).numpy()
# Out:
# array([[0.67261636, 0.32738367]], dtype=float32)

# %% [markdown]
# - 2*5 + 5
# - 5*5 + 5
# - 5*4 + 4
# - 4*3 + 3
# - 3*2 + 2

# %%
model.summary()
# Out:
# Model: "FirstModel"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ layer1 (Dense)                  │ (None, 5)              │            15 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer2 (Dense)                  │ (None, 5)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer3 (Dense)                  │ (None, 4)              │            24 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer4 (Dense)                  │ (None, 3)              │            15 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 2)              │             8 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 92 (368.00 B)
#  Trainable params: 92 (368.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
y_train[:1].shape, prediction.shape
# Out:
# ((1,), (1, 2))

# %% [markdown]
# tf.keras.losses.CategoricalCrossentropy

# %%
# y vector is sparse
# no activation in output layer
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True)

# %%
loss_fn(y_train[:1], prediction)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.1166225671768188>

# %%
model.compile(optimizer = 'adam', loss = loss_fn, metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=EPOCHS)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.4959 - loss: 0.6679 - val_accuracy: 0.5200 - val_loss: 0.6049
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5329 - loss: 0.5997 - val_accuracy: 0.5250 - val_loss: 0.5591
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6253 - loss: 0.5409 - val_accuracy: 0.7350 - val_loss: 0.5243
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7958 - loss: 0.5240 - val_accuracy: 0.8400 - val_loss: 0.4980
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8672 - loss: 0.4881 - val_accuracy: 0.8400 - val_loss: 0.4794
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8784 - loss: 0.4652 - val_accuracy: 0.8400 - val_loss: 0.4650
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8766 - loss: 0.4520 - val_accuracy: 0.8500 - val_loss: 0.4516
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8661 - loss: 0.4528 - val_accuracy: 0.8500 - val_loss: 0.4412
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8710 - loss: 0.4456 - val_accuracy: 0.8600 - val_loss: 0.4315
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8787 - loss: 0.4277 - val_accuracy: 0.8700 - val_loss: 0.4221
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8835 - loss: 0.4060 - val_accuracy: 0.8700 - val_loss: 0.4124
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8865 - loss: 0.4053 - val_accuracy: 0.8700 - val_loss: 0.4041
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8671 - loss: 0.4013 - val_accuracy: 0.8700 - val_loss: 0.3963
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8793 - loss: 0.4015 - val_accuracy: 0.8750 - val_loss: 0.3870
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8838 - loss: 0.3685 - val_accuracy: 0.8900 - val_loss: 0.3786
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8798 - loss: 0.3767 - val_accuracy: 0.8900 - val_loss: 0.3710
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9042 - loss: 0.3503 - val_accuracy: 0.8950 - val_loss: 0.3632
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.3450 - val_accuracy: 0.9000 - val_loss: 0.3548
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9029 - loss: 0.3477 - val_accuracy: 0.9100 - val_loss: 0.3473
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9060 - loss: 0.3269 - val_accuracy: 0.9150 - val_loss: 0.3389
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8878 - loss: 0.3503 - val_accuracy: 0.9200 - val_loss: 0.3325
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8864 - loss: 0.3462 - val_accuracy: 0.9150 - val_loss: 0.3254
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9012 - loss: 0.3311 - val_accuracy: 0.9200 - val_loss: 0.3178
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8953 - loss: 0.3278 - val_accuracy: 0.9200 - val_loss: 0.3109
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9105 - loss: 0.3055 - val_accuracy: 0.9150 - val_loss: 0.3047
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9135 - loss: 0.3175 - val_accuracy: 0.9200 - val_loss: 0.2972
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9181 - loss: 0.3002 - val_accuracy: 0.9150 - val_loss: 0.2917
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9314 - loss: 0.2721 - val_accuracy: 0.9200 - val_loss: 0.2842
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9154 - loss: 0.2943 - val_accuracy: 0.9200 - val_loss: 0.2771
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9317 - loss: 0.2806 - val_accuracy: 0.9150 - val_loss: 0.2734
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9309 - loss: 0.2749 - val_accuracy: 0.9200 - val_loss: 0.2669
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9814 - loss: 0.0892 - val_accuracy: 0.9600 - val_loss: 0.1197
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9771 - loss: 0.1003 - val_accuracy: 0.9600 - val_loss: 0.1211
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9668 - loss: 0.1084 - val_accuracy: 0.9600 - val_loss: 0.1208
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9669 - loss: 0.1000 - val_accuracy: 0.9550 - val_loss: 0.1178
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9786 - loss: 0.0894 - val_accuracy: 0.9550 - val_loss: 0.1202
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9806 - loss: 0.0886 - val_accuracy: 0.9600 - val_loss: 0.1156
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.1052 - val_accuracy: 0.9650 - val_loss: 0.1161
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9642 - loss: 0.0987 - val_accuracy: 0.9550 - val_loss: 0.1161
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9708 - loss: 0.1001 - val_accuracy: 0.9550 - val_loss: 0.1200
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9725 - loss: 0.1007 - val_accuracy: 0.9600 - val_loss: 0.1150
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9699 - loss: 0.0932 - val_accuracy: 0.9550 - val_loss: 0.1166
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9712 - loss: 0.0965 - val_accuracy: 0.9550 - val_loss: 0.1145
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9742 - loss: 0.0939 - val_accuracy: 0.9550 - val_loss: 0.1138
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0874 - val_accuracy: 0.9600 - val_loss: 0.1133
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9708 - loss: 0.1037 - val_accuracy: 0.9600 - val_loss: 0.1161
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9769 - loss: 0.0870 - val_accuracy: 0.9600 - val_loss: 0.1129
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9795 - loss: 0.0794 - val_accuracy: 0.9600 - val_loss: 0.1162
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0844 - val_accuracy: 0.9550 - val_loss: 0.1137
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9842 - loss: 0.0815 - val_accuracy: 0.9550 - val_loss: 0.1130
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.0868 - val_accuracy: 0.9600 - val_loss: 0.1166
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9745 - loss: 0.0861 - val_accuracy: 0.9600 - val_loss: 0.1112
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9789 - loss: 0.0852 - val_accuracy: 0.9550 - val_loss: 0.1133
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9733 - loss: 0.0832 - val_accuracy: 0.9600 - val_loss: 0.1156
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9724 - loss: 0.0905 - val_accuracy: 0.9550 - val_loss: 0.1134
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9741 - loss: 0.0927 - val_accuracy: 0.9550 - val_loss: 0.1120
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0778 - val_accuracy: 0.9600 - val_loss: 0.1089
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9815 - loss: 0.0798 - val_accuracy: 0.9550 - val_loss: 0.1137

# %%
hist_df = pd.DataFrame(history.history)
fig, axes = plt.subplots(1,2)
ax = axes[0]
hist_df.plot(y=['loss', 'val_loss'], ax=ax)
ax = axes[1]
hist_df.plot(y=['accuracy', 'val_accuracy'], ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ### Training Data

# %%
y_pred = model.predict(X_train)

accuracy_score(y_pred=y_pred.argmax(axis=1), y_true=y_train)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 0.97875

# %%
cm = confusion_matrix(y_pred=y_pred.argmax(axis=1), y_true=y_train)
cm
# Out:
# array([[392,   8],
#        [  9, 391]], dtype=int64)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1])

disp.plot(cmap='Blues', colorbar=False)
plt.grid()
plt.show()

# %% [markdown]
# ### Testing Data

# %%
y_pred = model.predict(X_test)


# calculate accuracy
print (f'Test Accuracy: {accuracy_score(y_pred=y_pred.argmax(axis=1), y_true=y_test)}')

# calculate confusion matrix
cm = confusion_matrix(y_pred=y_pred.argmax(axis=1), y_true=y_test)

# plots always look good
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1])

disp.plot(cmap='Blues', colorbar=False)
plt.grid()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Test Accuracy: 0.955

# %%
fn_plot_decision_boundary(model, X_train, y_train)
# Out:
# 5529/5529 ━━━━━━━━━━━━━━━━━━━━ 3s 525us/step
