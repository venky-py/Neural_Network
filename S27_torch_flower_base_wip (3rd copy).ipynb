# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Image Processing with Neural Network
# ## Session 27 :
# ## Working with PyTorch
# - Flowers DataSet with common transformation
# - ${ReLU}$ activation function
# - Regularizations:
#     - L2,
#     - BatchNorm,
#     - Dropout,
#     - Early Stopping

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd

from collections.abc import Callable
from typing import Literal


from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay, f1_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt


import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset

# New
from torchsummary import summary
from torchvision import datasets, transforms

from utils.helper import fn_plot_torch_hist, fn_plot_confusion_matrix

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../input'
outDir = '../output'
modelDir = '../models'
subDir = 'flower_photos'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
torch.manual_seed(RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 100 # number of epochs

BATCH_SIZE = 8

ALPHA = 0.001 # learning rate

TRAIN_SIZE = 92*32

# Input Image size
IMG_HEIGHT = 188
IMG_WIDTH = 188

# for early stopping 
PATIENCE = 10
LR_FACTOR = 0.1
LR_PATIENCE = 5

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 10),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

plt.rcParams.update(params) # update rcParams

CMAP = plt.cm.brg
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# ## Basic Hygiene

# %%
# Check if all directories are present
if not os.path.exists(os.path.join(outDir)):
    os.makedirs(os.path.join(outDir))
    print ('Created {} directory'.format(outDir))

if not os.path.exists(os.path.join(modelDir, subDir)):
    os.makedirs(os.path.join(modelDir, subDir))
    print ('Created {} directory'.format(os.path.join(modelDir, subDir)))

# %% [markdown]
# ## All about CUDA

# %%
print ('Is CUDA available: ', torch.cuda.is_available())

print ('CUDA version: ', torch.version.cuda )

print ('Current Device ID: ', torch.cuda.current_device())

print ('Name of the CUDA device: ', torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# Is CUDA available:  True
# CUDA version:  12.1
# Current Device ID:  0
# Name of the CUDA device:  NVIDIA GeForce RTX 2060 SUPER

# %%
# Get cpu or gpu device for training.

device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# ## Helper Functions

# %%
###-----------------------------------
### Function to plot Loss Curve
###-----------------------------------

def plot_torch_hist(hist_df : pd.DataFrame):
    '''
    Args:
      hist_df : pandas Dataframe with five columns
                First column need to be epoch, 'x' values
    '''
    # instantiate figure
    fig, axes = plt.subplots(1,2 , figsize = (15,6))
    
    facecolor = 'cyan'
    fontsize=12
    
    # Get columns by index to eliminate any column naming error
    x = hist_df.columns[0]
    y1 = hist_df.columns[1]
    y2 = hist_df.columns[2]
    y3 = hist_df.columns[3]
    y4 = hist_df.columns[4]

    
    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor=facecolor, alpha=0.5)
    
    # Where was min loss
    best = hist_df[hist_df[y2] == hist_df[y2].min()]
    
    # pick first axis
    ax = axes[0]

    # Plot all losses
    hist_df.plot(x = x, y = [y1,y2], ax = ax)

    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y2]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, 
            transform=ax.transAxes, 
            fontsize=fontsize,
            verticalalignment='top', 
            bbox=props)
    
    # Mark arrow at lowest
    offset = (best[y2].max() - best[y2].max())/10
    ax.annotate(f'Min: {best[y2].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y2].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()-2, best[y2].to_numpy()[0]+offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    # Draw vertical line at best value
    ax.axvline(x = best[x].to_numpy(), 
               color = 'green', 
               linestyle='-.', lw = 3);
    
    ax.set_xlabel(x.capitalize())
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid()
    ax.legend(loc = 'upper left') # model legend to upper left

    # pick second axis
    ax = axes[1]

    # Plot accuracy
    hist_df.plot(x = x, y = [y3, y4], ax = ax)

    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y3],
                           hist_df.iloc[-1][y4]) #text to plot
        
    # place a text box in lower middle in axes coords
    ax.text(0.3, 0.2, txtstr, 
            transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    offset = (best[y4].max() - best[y4].min())/10
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()-2, best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw a vertical line at best value
    ax.axvline(x = best[x].to_numpy(), 
               color = 'green', 
               linestyle='-.', lw = 3)
    
    # Labels
    ax.set_xlabel(x.capitalize())
    ax.set_ylabel(y3.capitalize())
    ax.set_title('Accuracies')
    ax.grid();
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %% [markdown]
# ## Read Flowers data set

# %%
###---------------
### Transformation
###---------------

transform = transforms.Compose([
    transforms.Resize(IMG_HEIGHT),
    transforms.CenterCrop(IMG_HEIGHT),
    transforms.ToTensor(),
    transforms.Normalize( mean = [0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  
])

data_dir = os.path.join(inpDir, subDir)

dataset = datasets.ImageFolder(data_dir, transform=transform)

# %%
image, label = next(iter(dataset))
image.shape, label
# Out:
# (torch.Size([3, 188, 188]), 0)

# %%
94*32
# Out:
# 3008

# %%
dataset_size = len(dataset)

train_size = TRAIN_SIZE

test_size = dataset_size - train_size
print (dataset_size, train_size, test_size)
# Out:
# 3670 2944 726

# %%
indices = torch.randperm(len(dataset)).tolist()
#indices

# pick up indices up to test_size
train_dataset = torch.utils.data.Subset(dataset,indices[:-test_size])

# pickup from test_size
test_dataset = torch.utils.data.Subset(dataset,indices[-test_size:])

# %%
class_names = {}
for count, name in enumerate(train_dataset.dataset.classes):
    class_names[count] = name
class_names
# Out:
# {0: 'daisy', 1: 'dandelion', 2: 'roses', 3: 'sunflowers', 4: 'tulips'}

# %%
numClasses = len(class_names)
numClasses
# Out:
# 5

# %%
next(iter(train_dataset))[0].shape
# Out:
# torch.Size([3, 188, 188])

# %% [markdown]
# ## Data Loader

# %%
#torch.utils.data.DataLoader?

# %%
train_dataloader = torch.utils.data.DataLoader(train_dataset, 
                                               batch_size=BATCH_SIZE,
                                               shuffle= True)

test_dataloader = torch.utils.data.DataLoader(test_dataset, 
                                               batch_size=BATCH_SIZE,
                                               shuffle= True)


trainSteps = len(train_dataloader.dataset) // BATCH_SIZE

testSteps = len(test_dataloader.dataset) // BATCH_SIZE

print (trainSteps, testSteps)
# Out:
# 368 90

# %%
def fn_showImages(img, ax):

    img = img.numpy().transpose((1,2,0))

    means = np.array([0.485, 0.456, 0.406])
    
    stds = np.array([0.229, 0.224, 0.225])
    
    img = stds * img + means
    
    img = np.clip(img, 0, 1)
    
    ax.imshow(img)

    ax.axis(False)

# %%
images, labels =next(iter(train_dataloader))

#print (images.shape, labels.shape)

fig = plt.figure(figsize=(15,15))

for i in range (BATCH_SIZE):

    ax = fig.add_subplot(BATCH_SIZE//8, 8, i+1)
    
    fn_showImages(images[i], ax)
    ax.set_title(class_names[labels[i].cpu().item()])

plt.tight_layout()

# %% [markdown]
# ## CNN Model

# %%
outChannels1 = 64
outChannels2 = 128
outChannels3 = 256
outChannels4 = 512
outChannels5 = 512
outChannels6 = 1024

numChannels = 3 ### Hard coded

dor1 = 0.1
dor2 = 0.1
dor3 = 0.1
dor4 = 0.1
dor5 = 0.6
dor6 = 0.6
dor7 = 0.6
dor8 = 0.6

model = nn.Sequential(

    ###------
    ### Set I
    ###------
    ## Conv2d ==> BN ==> LeakyReLU ==> DO ==> MaxPool2d
    nn.Conv2d(in_channels=numChannels, out_channels=outChannels1,
              kernel_size= (3,3),
              padding = 'same'), # 188 x 188 x 64
    nn.BatchNorm2d(outChannels1),
    nn.LeakyReLU(),
    
    nn.MaxPool2d(kernel_size=(2,2), stride=(2, 2)), #94 x 94 x 64
    nn.Dropout(dor1),
    
    
    ###------
    ### Set II
    ###------
    ## Conv2d ==> BN ==> LeakyReLU ==> DO ==> MaxPool2d
    nn.Conv2d(in_channels=outChannels1, out_channels=outChannels2,
              kernel_size= (3,3)), # 92 x 92 x 128
    nn.BatchNorm2d(outChannels2),
    nn.LeakyReLU(),
    
    nn.MaxPool2d(kernel_size=(2,2), stride=(2, 2)), #46 x 46 x 128
    nn.Dropout(dor2),
    
    ###------
    ### Set III
    ###------
    ## Conv2d ==> BN ==> LeakyReLU ==> DO ==> MaxPool2d
    nn.Conv2d(in_channels=outChannels2, out_channels=outChannels3,
              kernel_size= (3,3)), # 44 x 44 x 256
    
    nn.BatchNorm2d(outChannels3),
    nn.LeakyReLU(),
    
    nn.MaxPool2d(kernel_size=(2,2), stride=(2, 2)), #22 x 22 x 256
    nn.Dropout(dor3),
    
    ###------
    ### Set IV
    ###------
    ## Conv2d ==> BN ==> LeakyReLU ==> DO ==> MaxPool2d
    nn.Conv2d(in_channels=outChannels3, out_channels=outChannels4,
              kernel_size= (3,3)), #  20 x 20 x 512
    
    nn.BatchNorm2d(outChannels4),
    nn.LeakyReLU(),
    
    
    nn.MaxPool2d(kernel_size=(2,2), stride=(2, 2)), # 10 x 10 x 512
    nn.Dropout(dor4),
    
    ###------
    ### Set V
    ###------
    ## Conv2d ==> BN ==> LeakyReLU ==> DO ==> MaxPool2d
    nn.Conv2d(in_channels=outChannels4, out_channels=outChannels5,
              kernel_size= (3,3)), #  8 x 8 x 256
    
    nn.BatchNorm2d(outChannels5),
    nn.LeakyReLU(),
    

    nn.MaxPool2d(kernel_size=(2,2), stride=(2, 2)), # 4 x 4 x 512
    nn.Dropout(dor5),


    ###------
    ### Set VI
    ###------
    ## Conv2d ==> BN ==> LeakyReLU ==> DO ==> MaxPool2d
    nn.Conv2d(in_channels=outChannels5, out_channels=outChannels6,
              kernel_size= (3,3)), #  2 x 2 x 1024
    
    nn.BatchNorm2d(outChannels6),
    nn.LeakyReLU(),
    nn.Dropout(dor6),
    
    ###------
    ### Head
    ###------
    nn.Flatten(),

    nn.Linear( in_features= 2 * 2 *outChannels6, out_features=outChannels6//2),
    
    nn.BatchNorm1d(outChannels6//2),
    nn.LeakyReLU(),
    nn.Dropout(dor7),
    
    nn.Linear( in_features= outChannels6//2, out_features=outChannels6//16),
    
    nn.BatchNorm1d(outChannels6//16),
    nn.LeakyReLU(),
    nn.Dropout(dor8),

    nn.Linear( in_features= outChannels6//16, out_features=numClasses),            
 )

# %%
model = model.to(device)
print (model)
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.01)
#   (3): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (4): Dropout(p=0.1, inplace=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): LeakyReLU(negative_slope=0.01)
#   (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (9): Dropout(p=0.1, inplace=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#   (11): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): LeakyReLU(negative_slope=0.01)
#   (13): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (14): Dropout(p=0.1, inplace=False)
#   (15): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1))
#   (16): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (17): LeakyReLU(negative_slope=0.01)
#   (18): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (19): Dropout(p=0.1, inplace=False)
#   (20): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1))
#   (21): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): LeakyReLU(negative_slope=0.01)
#   (23): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (24): Dropout(p=0.6, inplace=False)
#   (25): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1))
#   (26): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (27): LeakyReLU(negative_slope=0.01)
#   (28): Dropout(p=0.6, inplace=False)
#   (29): Flatten(start_dim=1, end_dim=-1)
#   (30): Linear(in_features=4096, out_features=512, bias=True)
#   (31): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): LeakyReLU(negative_slope=0.01)
#   (33): Dropout(p=0.6, inplace=False)
#   (34): Linear(in_features=512, out_features=64, bias=True)
#   (35): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (36): LeakyReLU(negative_slope=0.01)
#   (37): Dropout(p=0.6, inplace=False)
#   (38): Linear(in_features=64, out_features=5, bias=True)
# )

# %%
#list(model.parameters())

# %%
# for data in train_dataloader:
#     print (data)

# %%
_ = summary(model, (3, 188, 188))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 188, 188]           1,792
#        BatchNorm2d-2         [-1, 64, 188, 188]             128
#          LeakyReLU-3         [-1, 64, 188, 188]               0
#          MaxPool2d-4           [-1, 64, 94, 94]               0
#            Dropout-5           [-1, 64, 94, 94]               0
#             Conv2d-6          [-1, 128, 92, 92]          73,856
#        BatchNorm2d-7          [-1, 128, 92, 92]             256
#          LeakyReLU-8          [-1, 128, 92, 92]               0
#          MaxPool2d-9          [-1, 128, 46, 46]               0
#           Dropout-10          [-1, 128, 46, 46]               0
#            Conv2d-11          [-1, 256, 44, 44]         295,168
#       BatchNorm2d-12          [-1, 256, 44, 44]             512
#         LeakyReLU-13          [-1, 256, 44, 44]               0
#         MaxPool2d-14          [-1, 256, 22, 22]               0
#           Dropout-15          [-1, 256, 22, 22]               0
#            Conv2d-16          [-1, 512, 20, 20]       1,180,160
#       BatchNorm2d-17          [-1, 512, 20, 20]           1,024
#         LeakyReLU-18          [-1, 512, 20, 20]               0
#         MaxPool2d-19          [-1, 512, 10, 10]               0
#           Dropout-20          [-1, 512, 10, 10]               0
#            Conv2d-21            [-1, 512, 8, 8]       2,359,808
#       BatchNorm2d-22            [-1, 512, 8, 8]           1,024
#         LeakyReLU-23            [-1, 512, 8, 8]               0
#         MaxPool2d-24            [-1, 512, 4, 4]               0
#           Dropout-25            [-1, 512, 4, 4]               0
#            Conv2d-26           [-1, 1024, 2, 2]       4,719,616
#       BatchNorm2d-27           [-1, 1024, 2, 2]           2,048
#         LeakyReLU-28           [-1, 1024, 2, 2]               0
#           Dropout-29           [-1, 1024, 2, 2]               0
#           Flatten-30                 [-1, 4096]               0
#            Linear-31                  [-1, 512]       2,097,664
#       BatchNorm1d-32                  [-1, 512]           1,024
#         LeakyReLU-33                  [-1, 512]               0
#           Dropout-34                  [-1, 512]               0
#            Linear-35                   [-1, 64]          32,832
#       BatchNorm1d-36                   [-1, 64]             128
#         LeakyReLU-37                   [-1, 64]               0
#           Dropout-38                   [-1, 64]               0
#            Linear-39                    [-1, 5]             325
# ================================================================
# Total params: 10,767,365
# Trainable params: 10,767,365
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.40
# Forward/backward pass size (MB): 109.08
# Params size (MB): 41.07
# Estimated Total Size (MB): 150.56
# ----------------------------------------------------------------

# %%
loss_fn = nn.CrossEntropyLoss(reduction='sum') # computes the cross entropy loss between input logits and target.



loss, tloss = [],[]
acc, tacc = [],[]
n_epoch = []


optimizer = torch.optim.AdamW(model.parameters(),
                             lr=ALPHA, 
                             weight_decay=0.1e-4)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 
                                                     mode='min', 
                                                     factor=LR_FACTOR, 
                                                     patience=LR_PATIENCE,
                                                     min_lr=1e-5)

# Min Loss
minLoss = float('inf')

# Path to save the model
savePath = os.path.join(modelDir, subDir, 'bn_do_flat.pth')

# Train the model for multiple epochs
for epoch in range (EPOCHS):
    
    # Training loop
    train_loss = 0.0
    train_acc = 0.0
    model.train() # Set the model in training mode
    for data in train_dataloader:
        
        inputs, labels = data
        
        inputs = inputs.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
    
        outputs = model(inputs)
        _, y_pred = torch.max(outputs, 1) # max along an axis gives both max val as well as index
        
        batch_loss = loss_fn(outputs, labels) # average loss of the batch
        batch_acc = accuracy_score(labels.cpu().numpy(), y_pred.cpu().numpy())
        # Back prop
        optimizer.zero_grad()
        batch_loss.backward()
        optimizer.step()
        
        train_loss += batch_loss.item()* inputs.size(0)
        train_acc += batch_acc * inputs.size(0)

    train_loss /= train_size
    train_acc /= train_size
    
    loss.append(train_loss)
    acc.append(train_acc)
    
    # Testing loop
    test_loss = 0.0
    test_acc = 0.0
    
    with torch.no_grad():
        
        model.eval() # evaluation mode
    
        for data in test_dataloader:
            
            inputs, labels = data            
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            
            outputs = model(inputs)
            
            _, y_pred = torch.max(outputs, 1) # max along an axis gives both max val as well as index
             
            batch_loss = loss_fn(outputs, labels)
            
            batch_acc = accuracy_score(labels.cpu().numpy(), y_pred.cpu().numpy())
            
            test_loss += batch_loss.item() * inputs.size(0)
            test_acc += batch_acc* inputs.size(0)

        
        test_loss /= test_size
        test_acc /= test_size
    
        tloss.append(test_loss)
        tacc.append(test_acc)
    
    n_epoch.append(epoch)
    
        # Step the scheduler
    scheduler.step(test_loss)

    ##### Add Early stopping/ Saving Model #####
    if test_loss < minLoss:
        minLoss = test_loss
        counter = 0
        # Saving Model
        torch.save({ 'epoch': epoch + 1,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'loss': loss_fn,}, savePath )

    else:
        counter +=1
    if counter > PATIENCE:
        break
    #-----------------------------

    #if epoch%10 == 0:
    print(f'At epoch {epoch:>3d} | Loss - train:{train_loss:.4f}, test:{test_loss:.4f} | Acc - train:{train_acc:.4f}, test:{test_acc:.4f}')
# Out:
# At epoch   0 | Loss - train:11.3696, test:9.4701 | Acc - train:0.3991, test:0.5248
# At epoch   1 | Loss - train:10.1814, test:8.7668 | Acc - train:0.4925, test:0.5606
# At epoch   2 | Loss - train:9.5156, test:8.6868 | Acc - train:0.5346, test:0.5606
# At epoch   3 | Loss - train:9.0510, test:7.7010 | Acc - train:0.5611, test:0.6171
# At epoch   4 | Loss - train:8.9111, test:7.4029 | Acc - train:0.5832, test:0.6625
# At epoch   5 | Loss - train:8.5501, test:7.0578 | Acc - train:0.6016, test:0.6818
# At epoch   6 | Loss - train:8.2332, test:7.3464 | Acc - train:0.6162, test:0.6736
# At epoch   7 | Loss - train:8.2211, test:6.9732 | Acc - train:0.6260, test:0.6625
# At epoch   8 | Loss - train:8.0478, test:6.6795 | Acc - train:0.6291, test:0.6983
# At epoch   9 | Loss - train:7.9470, test:6.5715 | Acc - train:0.6386, test:0.6997
# At epoch  10 | Loss - train:7.6271, test:6.3368 | Acc - train:0.6610, test:0.7094
# At epoch  11 | Loss - train:7.6387, test:6.1268 | Acc - train:0.6562, test:0.7355
# At epoch  12 | Loss - train:7.3331, test:6.2287 | Acc - train:0.6756, test:0.7052
# At epoch  13 | Loss - train:7.1038, test:5.8984 | Acc - train:0.6834, test:0.7562
# At epoch  14 | Loss - train:7.2060, test:5.6719 | Acc - train:0.6831, test:0.7273
# At epoch  15 | Loss - train:6.6860, test:5.6318 | Acc - train:0.7099, test:0.7452
# At epoch  16 | Loss - train:6.6222, test:5.3978 | Acc - train:0.7140, test:0.7507
# At epoch  17 | Loss - train:6.2109, test:5.2301 | Acc - train:0.7289, test:0.7755
# At epoch  18 | Loss - train:6.3644, test:5.5420 | Acc - train:0.7208, test:0.7369
# At epoch  19 | Loss - train:5.9227, test:5.0950 | Acc - train:0.7459, test:0.7837
# At epoch  20 | Loss - train:6.0686, test:5.1616 | Acc - train:0.7283, test:0.7810
# At epoch  21 | Loss - train:5.7874, test:5.3414 | Acc - train:0.7449, test:0.7590
# At epoch  22 | Loss - train:5.8040, test:5.7879 | Acc - train:0.7388, test:0.7493
# At epoch  23 | Loss - train:5.6239, test:5.0784 | Acc - train:0.7517, test:0.7700
# At epoch  24 | Loss - train:5.4227, test:4.7730 | Acc - train:0.7673, test:0.7920
# At epoch  25 | Loss - train:4.9967, test:4.8187 | Acc - train:0.7867, test:0.7700
# At epoch  26 | Loss - train:5.0398, test:4.8979 | Acc - train:0.7816, test:0.7796
# At epoch  27 | Loss - train:4.8842, test:4.6885 | Acc - train:0.7952, test:0.7837
# At epoch  28 | Loss - train:4.4885, test:4.4916 | Acc - train:0.8023, test:0.7920
# At epoch  29 | Loss - train:4.4863, test:4.5893 | Acc - train:0.8135, test:0.7989
# At epoch  30 | Loss - train:4.3592, test:4.7524 | Acc - train:0.8183, test:0.8030
# At epoch  31 | Loss - train:4.2298, test:4.6831 | Acc - train:0.8281, test:0.7810
# At epoch  32 | Loss - train:3.9758, test:4.4565 | Acc - train:0.8213, test:0.8072
# At epoch  33 | Loss - train:3.9254, test:5.0520 | Acc - train:0.8390, test:0.7700
# At epoch  34 | Loss - train:3.8565, test:4.8677 | Acc - train:0.8400, test:0.7879
# At epoch  35 | Loss - train:3.7334, test:4.4641 | Acc - train:0.8424, test:0.8058
# At epoch  36 | Loss - train:3.2993, test:4.4435 | Acc - train:0.8635, test:0.7961
# At epoch  37 | Loss - train:3.3987, test:4.6713 | Acc - train:0.8570, test:0.7934
# At epoch  38 | Loss - train:3.4742, test:4.7648 | Acc - train:0.8536, test:0.7934
# At epoch  39 | Loss - train:3.1203, test:4.7177 | Acc - train:0.8706, test:0.7975
# At epoch  40 | Loss - train:2.9458, test:4.6899 | Acc - train:0.8855, test:0.7906
# At epoch  41 | Loss - train:3.1302, test:4.9135 | Acc - train:0.8665, test:0.7837
# At epoch  42 | Loss - train:3.0852, test:4.6820 | Acc - train:0.8747, test:0.8017
# At epoch  43 | Loss - train:2.3738, test:4.1592 | Acc - train:0.9086, test:0.8140
# At epoch  44 | Loss - train:2.0861, test:4.1837 | Acc - train:0.9181, test:0.8278
# At epoch  45 | Loss - train:2.0486, test:4.2034 | Acc - train:0.9209, test:0.8251
# At epoch  46 | Loss - train:2.0712, test:4.4465 | Acc - train:0.9181, test:0.8182
# At epoch  47 | Loss - train:2.0788, test:4.1950 | Acc - train:0.9222, test:0.8182
# At epoch  48 | Loss - train:2.0049, test:4.2375 | Acc - train:0.9215, test:0.8209
# At epoch  49 | Loss - train:1.9020, test:4.1981 | Acc - train:0.9290, test:0.8168
# At epoch  50 | Loss - train:1.9848, test:4.3182 | Acc - train:0.9249, test:0.8168
# At epoch  51 | Loss - train:1.8317, test:4.2535 | Acc - train:0.9307, test:0.8251
# At epoch  52 | Loss - train:2.0239, test:4.2875 | Acc - train:0.9198, test:0.8223
# At epoch  53 | Loss - train:1.8527, test:4.2944 | Acc - train:0.9297, test:0.8154

# %%
loss_df = pd.DataFrame({'epoch'     : n_epoch,
                        'loss'      : loss,
                        'test_loss' : tloss,
                        'acc'       : acc,
                        'test_acc'  : tacc})

# %%
loss_df[loss_df['test_loss'] == loss_df['test_loss'].min()]
# Out:
#     epoch      loss  test_loss       acc  test_acc
# 43     43  2.373778   4.159152  0.908628   0.81405

# %%
fn_plot_torch_hist(loss_df)

# %% [markdown]
# ## Accuracies

# %%
y_pred, y_true = [], []

###-------------
### Train dataset
###-------------
for data in train_dataloader:
    # get input data
    X_train, y_train = data
    X_train = X_train.to(device)

    y_true.extend(y_train)

    # make predictions
    pred_out = model(X_train)
    _, pred = torch.max(pred_out, 1) # max along an axis gives both max val as well as index

    # move over to cpu
    #y_train = y_train# .cpu()
    pred = pred.data.cpu()

    y_pred.extend(pred)


print ('Training accuracy : {:.4f}'.format(accuracy_score(y_true, y_pred)))
# Out:
# Training accuracy : 0.9980

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       502
#            1       1.00      1.00      1.00       718
#            2       0.99      1.00      1.00       524
#            3       1.00      1.00      1.00       562
#            4       1.00      0.99      1.00       638
#
#     accuracy                           1.00      2944
#    macro avg       1.00      1.00      1.00      2944
# weighted avg       1.00      1.00      1.00      2944

# %%
fn_plot_confusion_matrix(y_true, y_pred, class_names)

# %%
###-------------
### Test dataset
###-------------
y_pred, y_true = [], []

for data in test_dataloader:
    # get input data
    X_test, y_test = data
    X_test = X_test.to(device)

    y_true.extend(y_test)

    # make predictions
    pred_out = model(X_test)
    _, pred = torch.max(pred_out, 1) # max along an axis gives both max val as well as index

    # move over to cpu
    #y_train = y_train# .cpu()
    pred = pred.data.cpu()

    y_pred.extend(pred)


print ('Testing accuracy : {:.4f}'.format(accuracy_score(y_true, y_pred)))
# Out:
# Testing accuracy : 0.8182

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.84       131
#            1       0.86      0.81      0.83       180
#            2       0.67      0.82      0.74       117
#            3       0.91      0.85      0.88       137
#            4       0.85      0.75      0.79       161
#
#     accuracy                           0.82       726
#    macro avg       0.82      0.82      0.82       726
# weighted avg       0.83      0.82      0.82       726

# %%
fn_plot_confusion_matrix(y_true, y_pred, class_names)

# %%
print(f'F1 score:{f1_score(y_true, y_pred, average="weighted")}')
# Out:
# F1 score:0.8195240147615032

# %%
def filter_incorrect_predictions_batched(dataset, model, device):
    '''
    Args:
        dataset : PyTorch DataLoader (batched dataset)
        model : PyTorch model
        device : the device (CPU or GPU) on which the model is located
    Return:
        incorrect_samples (list) : [(image, label, prediction)]
    '''
    # to collect incorrect results
    incorrect_samples = []

    # Set the model to evaluation mode
    model.eval()

    with torch.no_grad():  # Disable gradient computation for inference
        for batch_images, batch_labels in dataset:
            # Move batch to the same device as the model
            batch_images = batch_images.to(device)
            batch_labels = batch_labels.to(device)

            # Get predictions for the batch
            yhat = model(batch_images)
            _, y_pred = torch.max(yhat, dim=1)  # Get the index of the max prediction for each sample

            # Compare predictions with true labels
            incorrect_indices = (y_pred != batch_labels)  # Find incorrect predictions

            # Extract incorrect samples from the batch
            for idx in torch.nonzero(incorrect_indices).squeeze():  # Get indices where predictions are incorrect
                incorrect_samples.append(
                    (batch_images[idx].cpu(), batch_labels[idx].cpu(), y_pred[idx].cpu())  # Move to CPU for collection
                )

    return incorrect_samples

# Use the function to collect incorrect predictions
# Example usage: assuming your model and data are on GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)  # Move model to the correct device
incorrect_examples = filter_incorrect_predictions_batched(test_dataloader, model, device)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 41
#      39 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      40 model.to(device)  # Move model to the correct device
# ---> 41 incorrect_examples = filter_incorrect_predictions_batched(test_dataloader, model, device)
#
# Cell In[36], line 30, in filter_incorrect_predictions_batched(dataset, model, device)
#      27         incorrect_indices = (y_pred != batch_labels)  # Find incorrect predictions
#      29         # Extract incorrect samples from the batch
# ---> 30         for idx in torch.nonzero(incorrect_indices).squeeze():  # Get indices where predictions are incorrect
#      31             incorrect_samples.append(
#      32                 (batch_images[idx].cpu(), batch_labels[idx].cpu(), y_pred[idx].cpu())  # Move to CPU for collection
#      33             )
#      35 return incorrect_samples
#
# File ~/Dec2024/lib/python3.8/site-packages/torch/_tensor.py:1043, in Tensor.__iter__(self)
#    1033 def __iter__(self):
#    1034     # NB: we use 'imap' and not 'map' here, so that in Python 2 we get a
#    1035     # generator and don't eagerly perform all the indexes.  This could
#    (...)
#    1040     # NB: We have intentionally skipped __torch_function__ dispatch here.
#    1041     # See gh-54457
#    1042     if self.dim() == 0:
# -> 1043         raise TypeError("iteration over a 0-d tensor")
#    1044     if torch._C._get_tracing_state():
#    1045         warnings.warn(
#    1046             "Iterating over a tensor might cause the trace to be incorrect. "
#    1047             "Passing a tensor of different shape won't change the number of "
#    (...)
#    1051             stacklevel=2,
#    1052         )
#
# TypeError: iteration over a 0-d tensor

# %%
fig = plt.figure(figsize=(15, 15))

fig.subplots_adjust(left=0, right=1,
                   bottom=0, top=1,
                   hspace=0.05, wspace=0.05)  # Adjust subplots

fntsize = 12

for i in range(min(80, len(incorrect_examples))):  
    image = incorrect_examples[i][0]
    label = incorrect_examples[i][1].item()
    pred = incorrect_examples[i][2].item()

    # Check if label matches the prediction
    if label != pred:
        color = 'red'
    else:
        color = 'cyan'

    prop = dict(boxstyle='round', facecolor=color, alpha=0.5)

    # Add a subplot to the figure
    ax = fig.add_subplot(8, 10, (i + 1), xticks=[], yticks=[])  # 8 rows and 10 columns
    #ax.imshow(np.transpose(image.cpu().numpy(), (1, 2, 0)), cmap=plt.cm.viridis, interpolation='nearest')  # Handle image format
    
    ax.set_title(class_names[label], fontsize=fntsize)  # Add true label as xlabel
    ax.text(0.1, 0.95, class_names[pred], transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=prop)  # Add predicted label as text in the box
    fn_showImages(image, ax)

fig.suptitle('Incorrect Predictions', fontsize=16)
plt.tight_layout()
plt.show()

# %%
class_names[label]
